# %%
import os
import re
import pandas as pd

path_tsplib = r'version1/data/test/TSPLIB/'
files = [f for f in os.listdir(path=path_tsplib) if f.endswith('.tsp')]

problem_set = []
for item in files:
    problem = {'name': item, 'size': int(re.findall('[0-9]+', item)[0])}
    problem_set.append(problem)

#order problem set by size, ranging from 100 to 1748
problem_set.sort(key=lambda x: x['size'], reverse=False)

df_ps = pd.DataFrame.from_dict(problem_set)

# %%
df_ps
# Out:
#            name  size
# 0     rd100.tsp   100
# 1   kroA100.tsp   100
# 2   kroC100.tsp   100
# 3    eil101.tsp   101
# 4    lin105.tsp   105
# 5     pr107.tsp   107
# 6     pr124.tsp   124
# 7   bier127.tsp   127
# 8     ch130.tsp   130
# 9     pr136.tsp   136
# 10    gr137.tsp   137
# 11    pr144.tsp   144
# 12  kroA150.tsp   150
# 13    pr152.tsp   152
# 14     u159.tsp   159
# 15   rat195.tsp   195
# 16     d198.tsp   198
# 17  kroA200.tsp   200
# 18    gr202.tsp   202
# 19   tsp225.tsp   225
# 20    ts225.tsp   225
# 21    pr226.tsp   226
# 22    gr229.tsp   229
# 23   gil262.tsp   262
# 24    pr264.tsp   264
# 25     a280.tsp   280
# 26    pr299.tsp   299
# 27   lin318.tsp   318
# 28    rd400.tsp   400
# 29    fl417.tsp   417
# 30    gr431.tsp   431
# 31    pr439.tsp   439
# 32   pcb442.tsp   442
# 33     d493.tsp   493
# 34   att532.tsp   532
# 35     u574.tsp   574
# 36   rat575.tsp   575
# 37     d657.tsp   657
# 38    gr666.tsp   666
# 39     u724.tsp   724
# 40   rat783.tsp   783
# 41   pr1002.tsp  1002
# 42    u1060.tsp  1060
# 43   vm1084.tsp  1084
# 44  pcb1173.tsp  1173
# 45    d1291.tsp  1291
# 46   rl1304.tsp  1304
# 47   rl1323.tsp  1323
# 48  nrw1379.tsp  1379
# 49   fl1400.tsp  1400
# 50    u1432.tsp  1432
# 51   fl1577.tsp  1577
# 52    d1655.tsp  1655
# 53   vm1748.tsp  1748
